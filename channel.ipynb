# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#copy file path by Cmd-Opt-C
df = pd.read_csv(r'/Users/shunhuawei/Desktop/archive/Channel_attribution.csv')

# %%
df.head(15)
# Out:
#     R05A.01  R05A.02  R05A.03  R05A.04  R05A.05  R05A.06  R05A.07  R05A.08  \
# 0        16        4      3.0      5.0     10.0      8.0      6.0      8.0
# 1         2        1      9.0     10.0      1.0      4.0      3.0     21.0
# 2         9       13     20.0     16.0     15.0     21.0      NaN      NaN
# 3         8       15     20.0     21.0      NaN      NaN      NaN      NaN
# 4        16        9     13.0     20.0     21.0      NaN      NaN      NaN
# 5         1       11      8.0      4.0      9.0     21.0      NaN      NaN
# 6         1        6     10.0     13.0     16.0     20.0     11.0     21.0
# 7        10       11     12.0      4.0     20.0     21.0      NaN      NaN
# 8        16       10      4.0     20.0     21.0      NaN      NaN      NaN
# 9         4       16     15.0     20.0     21.0      NaN      NaN      NaN
# 10        2       10     21.0      NaN      NaN      NaN      NaN      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 21 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   R05A.01  2392 non-null   int64
#  1   R05A.02  2392 non-null   int64
#  2   R05A.03  2384 non-null   float64
#  3   R05A.04  2217 non-null   float64
#  4   R05A.05  1586 non-null   float64
#  5   R05A.06  1030 non-null   float64
#  6   R05A.07  605 non-null    float64
#  7   R05A.08  391 non-null    float64
#  8   R05A.09  228 non-null    float64
#  9   R05A.10  138 non-null    float64
#  10  R05A.11  82 non-null     float64
#  11  R05A.12  52 non-null     float64
#  12  R05A.13  29 non-null     float64
#  13  R05A.14  19 non-null     float64
#  14  R05A.15  8 non-null      float64
#  15  R05A.16  7 non-null      float64
#  16  R05A.17  4 non-null      float64
#  17  R05A.18  2 non-null      float64
#  18  R05A.19  1 non-null      float64
#  19  R05A.20  1 non-null      float64
# ...

# %%
#Linear_touch

# %%
#DataFrame into a numpy array
df.to_numpy()
# Out:
# array([[16.,  4.,  3., ..., nan, nan, nan],
#        [ 2.,  1.,  9., ..., nan, nan, nan],
#        [ 9., 13., 20., ..., nan, nan, nan],
#        ...,
#        [10.,  6.,  5., ..., nan, nan, nan],
#        [10.,  6., 11., ..., nan, nan, nan],
#        [ 1.,  4.,  9., ..., nan, nan, nan]])

# %%
#convert dataframe to list
data_list = df.to_numpy().tolist()
print(data_list)
# Out:
# [[16.0, 4.0, 3.0, 5.0, 10.0, 8.0, 6.0, 8.0, 13.0, 20.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [2.0, 1.0, 9.0, 10.0, 1.0, 4.0, 3.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [9.0, 13.0, 20.0, 16.0, 15.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [8.0, 15.0, 20.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [16.0, 9.0, 13.0, 20.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [1.0, 11.0, 8.0, 4.0, 9.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [1.0, 6.0, 10.0, 13.0, 16.0, 20.0, 11.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [10.0, 11.0, 12.0, 4.0, 20.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [16.0, 10.0, 4.0, 20.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# ...

# %%
#The list of lists
flattened_list = []

#flatten the lis
for x in data_list:
    for y in x:
        if str(y) != 'nan':
            flattened_list.append(y)

print(flattened_list)
# Out:
# [16.0, 4.0, 3.0, 5.0, 10.0, 8.0, 6.0, 8.0, 13.0, 20.0, 21.0, 2.0, 1.0, 9.0, 10.0, 1.0, 4.0, 3.0, 21.0, 9.0, 13.0, 20.0, 16.0, 15.0, 21.0, 8.0, 15.0, 20.0, 21.0, 16.0, 9.0, 13.0, 20.0, 21.0, 1.0, 11.0, 8.0, 4.0, 9.0, 21.0, 1.0, 6.0, 10.0, 13.0, 16.0, 20.0, 11.0, 21.0, 10.0, 11.0, 12.0, 4.0, 20.0, 21.0, 16.0, 10.0, 4.0, 20.0, 21.0, 4.0, 16.0, 15.0, 20.0, 21.0, 2.0, 10.0, 21.0, 13.0, 9.0, 9.0, 21.0, 9.0, 3.0, 4.0, 9.0, 16.0, 10.0, 20.0, 21.0, 3.0, 4.0, 9.0, 15.0, 20.0, 21.0, 10.0, 16.0, 3.0, 20.0, 21.0, 13.0, 9.0, 16.0, 13.0, 20.0, 21.0, 9.0, 10.0, 20.0, 21.0, 9.0, 16.0, 20.0, 21.0, 4.0, 17.0, 20.0, 21.0, 10.0, 3.0, 20.0, 21.0, 10.0, 9.0, 11.0, 20.0, 21.0, 15.0, 8.0, 10.0, 20.0, 21.0, 2.0, 3.0, 4.0, 7.0, 7.0, 13.0, 20.0, 21.0, 11.0, 12.0, 9.0, 21.0, 9.0, 2.0, 16.0, 20.0, 21.0, 13.0, 9.0, 21.0, 4.0, 9.0, 20.0, 21.0, 14.0, 14.0, 20.0, 21.0, 16.0, 20.0, 21.0, 10.0, 4.0, 3.0, 5.0, 9.0, 11.0, 13.0, 16.0, 17.0, 20.0, 21.0, 10.0, 4.0, 9.0, 21.0, 9.0, 11.0, 4.0, 20.0, 21.0, 10.0, 3.0, 16.0, 17.
# ...

# %%
flattened_list = [int(x) for x in flattened_list]
print(flattened_list)
# Out:
# [16, 4, 3, 5, 10, 8, 6, 8, 13, 20, 21, 2, 1, 9, 10, 1, 4, 3, 21, 9, 13, 20, 16, 15, 21, 8, 15, 20, 21, 16, 9, 13, 20, 21, 1, 11, 8, 4, 9, 21, 1, 6, 10, 13, 16, 20, 11, 21, 10, 11, 12, 4, 20, 21, 16, 10, 4, 20, 21, 4, 16, 15, 20, 21, 2, 10, 21, 13, 9, 9, 21, 9, 3, 4, 9, 16, 10, 20, 21, 3, 4, 9, 15, 20, 21, 10, 16, 3, 20, 21, 13, 9, 16, 13, 20, 21, 9, 10, 20, 21, 9, 16, 20, 21, 4, 17, 20, 21, 10, 3, 20, 21, 10, 9, 11, 20, 21, 15, 8, 10, 20, 21, 2, 3, 4, 7, 7, 13, 20, 21, 11, 12, 9, 21, 9, 2, 16, 20, 21, 13, 9, 21, 4, 9, 20, 21, 14, 14, 20, 21, 16, 20, 21, 10, 4, 3, 5, 9, 11, 13, 16, 17, 20, 21, 10, 4, 9, 21, 9, 11, 4, 20, 21, 10, 3, 16, 17, 15, 21, 16, 20, 17, 21, 17, 15, 20, 21, 13, 10, 3, 7, 20, 21, 4, 5, 16, 20, 21, 2, 20, 6, 21, 10, 12, 4, 11, 20, 3, 1, 9, 15, 21, 3, 13, 20, 21, 9, 3, 6, 10, 21, 6, 1, 4, 11, 3, 20, 21, 2, 13, 21, 16, 20, 13, 21, 16, 3, 16, 20, 21, 2, 11, 20, 21, 4, 2, 9, 20, 21, 10, 13, 17, 16, 20, 21, 10, 3, 4, 9, 17, 20, 21, 12, 11, 1, 2, 16, 20, 21, 9, 4, 10, 9,
# ...

# %%
print(len(flattened_list))
# Out:
# 13568

# %%
print(flattened_list.count(1))
print(flattened_list.count(2))
print(flattened_list.count(3))
print(flattened_list.count(4))
print(flattened_list.count(5))
print(flattened_list.count(6))
print(flattened_list.count(7))
print(flattened_list.count(8))
print(flattened_list.count(9))
print(flattened_list.count(10))
print(flattened_list.count(11))
print(flattened_list.count(12))
print(flattened_list.count(13))
print(flattened_list.count(14))
print(flattened_list.count(15))
print(flattened_list.count(16))
print(flattened_list.count(17))
print(flattened_list.count(18))
print(flattened_list.count(19))
# Out:
# 373
# 439
# 570
# 1164
# 373
# 284
# 188
# 273
# 879
# 1009
# 551
# 376
# 959
# 281
# 313
# 749
# 376
# 25
# 66

# %%
#Goal: get the LAST_TOUCH!!! (not 20 or 21 or nan)

# %%
data_list = df.to_numpy().tolist()
print(data_list)
# Out:
# [[16.0, 4.0, 3.0, 5.0, 10.0, 8.0, 6.0, 8.0, 13.0, 20.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [2.0, 1.0, 9.0, 10.0, 1.0, 4.0, 3.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [9.0, 13.0, 20.0, 16.0, 15.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [8.0, 15.0, 20.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [16.0, 9.0, 13.0, 20.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [1.0, 11.0, 8.0, 4.0, 9.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [1.0, 6.0, 10.0, 13.0, 16.0, 20.0, 11.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [10.0, 11.0, 12.0, 4.0, 20.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], [16.0, 10.0, 4.0, 20.0, 21.0, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# ...

# %%
#Steps for Purchase

# %%
data_list = [[i for i in nested if str(i) != 'nan'] for nested in data_list]

#get len of each sublist
steps_num = []
for element in data_list:
    steps_num.append(len(element))
print(steps_num)
# Out:
# [11, 8, 6, 4, 5, 6, 8, 6, 5, 5, 3, 4, 8, 6, 5, 6, 4, 4, 4, 4, 5, 5, 8, 4, 5, 3, 4, 4, 3, 11, 4, 5, 6, 4, 4, 6, 5, 4, 10, 4, 5, 7, 3, 4, 5, 4, 5, 6, 7, 7, 6, 8, 6, 5, 6, 3, 5, 10, 4, 4, 6, 3, 5, 5, 4, 6, 4, 5, 5, 7, 6, 5, 5, 4, 4, 5, 5, 6, 6, 11, 4, 5, 4, 9, 5, 7, 4, 5, 6, 4, 6, 5, 6, 4, 4, 5, 6, 9, 5, 4, 5, 6, 7, 4, 7, 3, 3, 6, 4, 8, 4, 6, 12, 4, 5, 4, 4, 8, 5, 4, 5, 6, 6, 4, 4, 10, 4, 4, 4, 5, 4, 4, 7, 6, 4, 5, 4, 4, 4, 10, 4, 4, 7, 5, 4, 7, 14, 4, 5, 5, 7, 5, 3, 5, 6, 8, 5, 5, 5, 5, 12, 4, 4, 4, 5, 7, 5, 8, 5, 5, 4, 8, 4, 6, 5, 8, 4, 14, 6, 6, 6, 5, 3, 4, 4, 9, 7, 8, 6, 6, 5, 5, 4, 4, 4, 6, 4, 7, 3, 5, 6, 5, 4, 4, 4, 5, 4, 5, 8, 7, 4, 7, 7, 4, 6, 4, 5, 4, 4, 3, 9, 7, 4, 4, 4, 5, 4, 11, 7, 6, 3, 6, 4, 8, 7, 8, 5, 7, 8, 7, 7, 4, 5, 4, 6, 3, 4, 7, 6, 3, 4, 4, 4, 5, 3, 6, 3, 6, 4, 6, 5, 7, 8, 5, 10, 6, 6, 7, 6, 6, 6, 4, 6, 4, 5, 9, 7, 12, 4, 8, 6, 6, 4, 4, 5, 4, 3, 4, 5, 9, 5, 10, 4, 4, 5, 7, 4, 12, 3, 7, 6, 3, 5, 7, 9, 4, 7, 8, 5, 6, 6, 6, 7, 5, 5, 9, 6, 4, 5, 6, 7, 8, 2, 6, 4, 4, 6, 
# ...

# %%
#Visualization of Numbers of Steps taken before Purhcase

# %%
y = steps_num
plt.hist(y);
plt.show()

# %%
stepsData = {'Numers_of_Steps': steps_num
        }
stepsNum = pd.DataFrame(stepsData)
print(stepsNum)
# Out:
#       Numers_of_Steps
# 0                  11
# 1                   8
# 2                   6
# 3                   4
# 4                   5
# ...               ...
# 2387                8
# 2388                6
# 2389                8
# 2390                5
# 2391                6
#
# [2392 rows x 1 columns]

# %%
sns.set_style(style="darkgrid")
ax = sns.countplot(x="Numers_of_Steps", data=stepsNum);
plt.title('Number of Steps for Purchase');

# %%
last_touch_list = []
for element in data_list:
    cleanedList = [x for x in element if str(x) != 'nan']
    mylist = list(filter((21.0).__ne__, cleanedList))
    mylist1 = list(filter((20.0).__ne__, mylist))
    y = int(mylist1[-1])
    last_touch_list.append(y)
print(last_touch_list)
# Out:
# [13, 3, 15, 15, 13, 9, 11, 4, 4, 15, 10, 9, 10, 15, 3, 13, 10, 16, 17, 3, 11, 10, 13, 9, 16, 9, 9, 14, 16, 17, 9, 4, 15, 17, 15, 7, 16, 6, 15, 13, 10, 3, 13, 13, 16, 11, 9, 16, 17, 16, 4, 13, 17, 16, 17, 16, 4, 15, 9, 12, 4, 17, 17, 8, 12, 9, 4, 4, 16, 12, 1, 4, 4, 14, 9, 16, 13, 16, 5, 11, 4, 17, 3, 17, 4, 9, 3, 10, 9, 8, 16, 2, 4, 15, 5, 9, 11, 15, 16, 16, 17, 14, 9, 13, 13, 13, 4, 14, 16, 16, 5, 17, 15, 3, 7, 13, 10, 11, 11, 17, 15, 13, 16, 4, 16, 17, 4, 14, 15, 1, 2, 11, 9, 2, 9, 9, 1, 3, 16, 15, 11, 13, 3, 10, 16, 13, 11, 4, 10, 3, 11, 12, 9, 9, 4, 17, 17, 13, 14, 16, 14, 3, 7, 4, 10, 16, 17, 14, 4, 9, 11, 2, 4, 8, 9, 5, 11, 11, 11, 2, 10, 5, 4, 4, 9, 12, 10, 16, 9, 4, 5, 16, 16, 13, 16, 5, 8, 14, 1, 16, 13, 3, 16, 16, 9, 16, 4, 11, 16, 15, 4, 16, 14, 15, 4, 9, 1, 9, 9, 13, 15, 17, 4, 9, 16, 13, 1, 9, 9, 17, 13, 3, 3, 17, 12, 14, 4, 16, 17, 13, 12, 16, 16, 16, 9, 9, 4, 4, 9, 8, 4, 15, 10, 4, 10, 13, 4, 16, 16, 9, 16, 9, 16, 12, 10, 7, 4, 17, 9, 9, 13, 16, 17, 16, 9, 10, 14, 2, 9
# ...

# %%
print(last_touch_list.count(1))
print(last_touch_list.count(2))
print(last_touch_list.count(3))
print(last_touch_list.count(4))
print(last_touch_list.count(5))
print(last_touch_list.count(6))
print(last_touch_list.count(7))
print(last_touch_list.count(8))
print(last_touch_list.count(9))
print(last_touch_list.count(10))
print(last_touch_list.count(11))
print(last_touch_list.count(12))
print(last_touch_list.count(13))
print(last_touch_list.count(14))
print(last_touch_list.count(15))
print(last_touch_list.count(16))
print(last_touch_list.count(17))
print(last_touch_list.count(18))
print(last_touch_list.count(19))
# Out:
# 56
# 71
# 99
# 283
# 73
# 43
# 38
# 62
# 199
# 133
# 139
# 92
# 256
# 103
# 172
# 318
# 214
# 15
# 26

# %%
update_data_list = []

for element in data_list:
    for num in element:
        if num != 20 and num != 21 and str(num) != 'nan':
            update_data_list.append(num)
    print(update_data_list)

# %%
#Get the last_touch_channel

last_touch_channel = []

for index, row in df.iterrows():
    list_row = list(row)
    update_list_row = []
    for num in list_row:
        if num != 20 and num != 21 and str(num) != 'nan':    #remove conversion & null values
            update_list_row.append(num)
            y = int(update_list_row[(len(update_list_row)-1)])
            print(y)

# %%
print(last_touch_channel.count(1))
print(last_touch_channel.count(2))
print(last_touch_channel.count(3))
print(last_touch_channel.count(4))
print(last_touch_channel.count(5))
print(last_touch_channel.count(6))
print(last_touch_channel.count(7))
print(last_touch_channel.count(8))
print(last_touch_channel.count(9))
print(last_touch_channel.count(10))
print(last_touch_channel.count(11))
print(last_touch_channel.count(12))
print(last_touch_channel.count(13))
print(last_touch_channel.count(14))
print(last_touch_channel.count(15))
print(last_touch_channel.count(16))
print(last_touch_channel.count(17))
print(last_touch_channel.count(18))
print(last_touch_channel.count(19))
# Out:
# 373
# 439
# 570
# 1164
# 373
# 284
# 188
# 273
# 879
# 1009
# 551
# 376
# 959
# 281
# 313
# 749
# 376
# 25
# 66

# %%
#first_touch_channel => (first column from dataframe)
first_touch_channel = df.loc[:,'R05A.01']
first_touch_channel = list(first_touch_channel)
print(first_touch_channel)
# Out:
# [16, 2, 9, 8, 16, 1, 1, 10, 16, 4, 2, 13, 9, 3, 10, 13, 9, 9, 4, 10, 10, 15, 2, 11, 9, 13, 4, 14, 16, 10, 10, 9, 10, 16, 17, 13, 4, 2, 10, 3, 9, 6, 2, 16, 16, 2, 4, 10, 10, 12, 9, 2, 16, 10, 1, 16, 10, 16, 10, 4, 3, 13, 1, 11, 10, 13, 9, 9, 9, 10, 10, 9, 13, 15, 1, 12, 3, 2, 2, 9, 13, 13, 16, 1, 13, 2, 9, 1, 10, 9, 2, 9, 3, 16, 2, 6, 13, 9, 4, 15, 13, 1, 9, 11, 10, 13, 4, 10, 9, 9, 10, 9, 13, 4, 9, 4, 9, 2, 10, 13, 5, 1, 9, 9, 4, 10, 9, 5, 16, 4, 9, 12, 1, 3, 14, 9, 13, 9, 10, 13, 10, 10, 1, 4, 13, 13, 10, 10, 4, 3, 14, 13, 9, 10, 13, 10, 13, 4, 4, 4, 10, 1, 11, 9, 13, 10, 14, 9, 9, 16, 3, 6, 16, 2, 10, 16, 5, 13, 4, 12, 13, 13, 10, 3, 13, 1, 8, 10, 3, 10, 2, 8, 9, 12, 13, 16, 9, 1, 1, 9, 4, 12, 11, 5, 4, 12, 13, 16, 13, 13, 4, 10, 2, 13, 13, 13, 4, 7, 10, 13, 10, 9, 9, 10, 13, 2, 4, 16, 9, 13, 10, 2, 5, 4, 1, 10, 10, 10, 10, 3, 16, 10, 14, 12, 6, 9, 13, 3, 9, 17, 15, 13, 2, 13, 10, 1, 3, 4, 11, 9, 4, 2, 1, 13, 9, 10, 17, 10, 9, 10, 10, 2, 3, 3, 9, 2, 7, 12, 10, 6, 10, 4, 10, 13, 10,
# ...

# %%
print(first_touch_channel.count(1))
print(first_touch_channel.count(2))
print(first_touch_channel.count(3))
print(first_touch_channel.count(4))
print(first_touch_channel.count(5))
print(first_touch_channel.count(6))
print(first_touch_channel.count(7))
print(first_touch_channel.count(8))
print(first_touch_channel.count(9))
print(first_touch_channel.count(10))
print(first_touch_channel.count(11))
print(first_touch_channel.count(12))
print(first_touch_channel.count(13))
print(first_touch_channel.count(14))
print(first_touch_channel.count(15))
print(first_touch_channel.count(16))
print(first_touch_channel.count(17))
print(first_touch_channel.count(18))
print(first_touch_channel.count(19))
# Out:
# 130
# 199
# 168
# 231
# 62
# 50
# 26
# 56
# 250
# 547
# 66
# 75
# 320
# 34
# 22
# 111
# 31
# 4
# 10

# %%
data = {'Channel_num': list(range(1,20)), 
        'First_touch_conversion':[130,199,168,231,62,50,26,56,250,547,66,75,320,34,22,111,31,4,10], 
        'Last_touch_conversion':[56,71,99,283,73,43,38,62,199,133,139,92,256,103,172,318,214,15,26],
        'Linear_touch_conversion':[373,439,570,1164,373,284,188,273,879,1009,551,376,959,281,313,749,376,25,66]
        }
df_table = pd.DataFrame(data)
print(df_table)
# Out:
#     Channel_num  First_touch_conversion  Last_touch_conversion  \
# 0             1                     130                     56
# 1             2                     199                     71
# 2             3                     168                     99
# 3             4                     231                    283
# 4             5                      62                     73
# 5             6                      50                     43
# 6             7                      26                     38
# 7             8                      56                     62
# 8             9                     250                    199
# 9            10                     547                    133
# 10           11                      66                    139
# 11           12                      75                     92
# 12           13                     320                    256
# 13           14                      34                    103
# ...

# %%
#Visualization let's go

# %%
#Barplot with Seaborn for First touch conversion
ax = sns.barplot(x="Channel_num", y="First_touch_conversion", data=df_table, palette="Blues_d")
plt.title("First Touch Conversion: Channels Comparison")
# Out:
# Text(0.5, 1.0, 'First Touch Conversion: Channels Comparison')

# %%
#Barplot with Seaborn for Last touch conversion
ax = sns.barplot(x="Channel_num", y="Last_touch_conversion", data=df_table, palette="Blues_d")
plt.title("Last Touch Conversion: Channels Comparison")
# Out:
# Text(0.5, 1.0, 'Last Touch Conversion: Channels Comparison')

# %%
#Barplot with Seaborn for Last touch conversion
ax = sns.barplot(x="Channel_num", y="Linear_touch_conversion", data=df_table, palette="Blues_d")
plt.title("Linear Touch Conversion: Channels Comparison")
# Out:
# Text(0.5, 1.0, 'Linear Touch Conversion: Channels Comparison')

# %%
#below are some trial codes (please ignore)

# %%
pip install markov-model-attribution
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
path = pd.read_csv(r'/Users/shunhuawei/Desktop/archive/Paths.csv')

# %%
path.head(5)
# Out:
#                         Path  Conversion
# 0             1 > 1 > 1 > 20           1
# 1            1 > 1 > 12 > 12           1
# 2  1 > 1 > 14 > 13 > 12 > 20           1
# 3    1 > 1 > 3 > 13 > 3 > 20           1
# 4        1 > 1 > 3 > 17 > 17           1

# %%
mypath = path["Path"]
pathList = list(mypath)
print(pathList)
# Out:
# ['1 > 1 > 1 > 20', '1 > 1 > 12 > 12', '1 > 1 > 14 > 13 > 12 > 20', '1 > 1 > 3 > 13 > 3 > 20', '1 > 1 > 3 > 17 > 17', '1 > 1 > 6 > 1 > 12 > 20 > 12', '1 > 1 > 8 > 1 > 20 > 8', '1 > 10 > 10 > 3 > 20 > 11 > 3', '1 > 10 > 12 > 13 > 14 > 16 > 20', '1 > 10 > 14 > 13 > 20', '1 > 10 > 2 > 14 > 13 > 20', '1 > 10 > 20', '1 > 10 > 4 > 17', '1 > 10 > 6 > 14 > 20', '1 > 10 > 6 > 17 > 20', '1 > 10 > 7 > 11 > 5 > 4 > 20', '1 > 10 > 9 > 16 > 15 > 17 > 20', '1 > 10 > 9 > 20', '1 > 11 > 8 > 4 > 9', '1 > 12 > 13 > 20', '1 > 12 > 15 > 20', '1 > 12 > 2 > 9 > 8 > 2 > 12 > 12', '1 > 12 > 3', '1 > 13 > 12 > 17 > 9', '1 > 13 > 13 > 20', '1 > 13 > 20', '1 > 13 > 3 > 10 > 20', '1 > 14 > 12 > 17 > 20', '1 > 15 > 12 > 7 > 20', '1 > 15 > 20', '1 > 15 > 5 > 20', '1 > 16 > 17 > 20 > 1', '1 > 16 > 20', '1 > 16 > 3 > 20', '1 > 17 > 20 > 14', '1 > 17 > 4 > 20', '1 > 2', '1 > 2 > 10 > 13 > 20', '1 > 2 > 10 > 9 > 13', '1 > 2 > 13 > 14 > 20', '1 > 2 > 13 > 4 > 11 > 10 > 3 > 12 > 14 > 16 > 2 > 20', '1 > 2 > 16 > 20', '1 >
# ...

# %%
#Each path should begin with "start" and end with either "conv" or "null".
#Each path should be delimited by " > "
#=> add 'start >' in front & '> conv' and '>null' at the end

# %%
import markov_model_attribution as mma
import pandas as pd

# generate a dataset
#Each path should begin with "start" and end with either "conv" or "null".
#Each path should be delimited by " > "

pathData = pd.DataFrame({'Path': ['start > 1 > 1 > null', 'start > 1 > 12 > conv', 'start > 1 > 14 > 13 > 12 > null', 'start > 1 > 3 > 13 > 3 > null', 'start > 1 > 3 > 17 > null']})

model = mma.run_model(paths=pathData)

# %%
print(model['markov_conversions'])
# Out:
# {'': 1.0}

# %%
print(model['removal_effects'])
# Out:
# {'': 1.0}

# %%
last_touch_channel = []
update_list_row = []

for index, row in df.iterrows():
    list_row = list(row)
    for num in list_row:
        if num != 20 and num != 21 and str(num) != 'nan':    #remove conversion & null values
            update_list_row.append(num)
    print(update_list_row)

# %%
first_row = df.iloc[0]

first_row_clean = [x for x in first_row if str(x) != 'nan' if str(x) != '20' if str(x) != '21']
print(first_row_clean)
last_num_index = len(first_row_clean)
print(first_row_clean[(last_num_index -1)])
# Out:
# [16.0, 4.0, 3.0, 5.0, 10.0, 8.0, 6.0, 8.0, 13.0, 20.0, 21.0]
# 21.0

# %%
sns.set_style(style="darkgrid")
ax = sns.countplot(x="Channel_num", data=data)
